-- %%
CREATE OR REFRESH STREAMING TABLE bronze_customers COMMENT "Raw Zomato customer data" TBLPROPERTIES ("quality" = "bronze") AS SELECT   *,   _metadata.file_path AS input_file_path,   CURRENT_TIMESTAMP AS ingestion_timestamp FROM cloud_files(   '/Volumes/dlt_manas/my_schema/delta_live_tables/Landing/operational_data/zomato/customers.csv',   'csv',   map(     'header','true',     'cloudFiles.inferColumnTypes','true'   ) );

-- %%
CREATE OR REFRESH STREAMING TABLE bronze_menuItems COMMENT "Raw Zomato menu data" TBLPROPERTIES ("quality" = "bronze") AS SELECT   *,   _metadata.file_path AS input_file_path,   CURRENT_TIMESTAMP AS ingestion_timestamp FROM cloud_files(   '/Volumes/dlt_manas/my_schema/delta_live_tables/Landing/operational_data/zomato/menu_items.csv',   'csv',   map(     'header','true',     'cloudFiles.inferColumnTypes','true'   ) );

-- %%
CREATE OR REFRESH STREAMING TABLE bronze_orders COMMENT "Raw Zomato orders data" TBLPROPERTIES ("quality" = "bronze") AS SELECT   *,   _metadata.file_path AS input_file_path,   CURRENT_TIMESTAMP AS ingestion_timestamp FROM cloud_files(   '/Volumes/dlt_manas/my_schema/delta_live_tables/Landing/operational_data/zomato/orders.csv.csv',   'csv',   map(     'header','true',     'cloudFiles.inferColumnTypes','true'   ) );

-- %%
CREATE OR REFRESH STREAMING TABLE bronze_restaurants COMMENT "Raw Zomato restaurants data" TBLPROPERTIES ("quality" = "bronze") AS SELECT   *,   _metadata.file_path AS input_file_path,   CURRENT_TIMESTAMP AS ingestion_timestamp FROM cloud_files(   '/Volumes/dlt_manas/my_schema/delta_live_tables/Landing/operational_data/zomato/restaurants.csv',   'csv',   map(     'header','true',     'cloudFiles.inferColumnTypes','true'   ) );

-- %%
CREATE OR REFRESH STREAMING TABLE bronze_operations COMMENT "Raw Zomato operations data" TBLPROPERTIES ("quality" = "bronze") AS SELECT   *,   _metadata.file_path AS input_file_path,   CURRENT_TIMESTAMP AS ingestion_timestamp FROM cloud_files(   '/Volumes/dlt_manas/my_schema/delta_live_tables/Landing/operational_data/zomato/operations.csv',   'csv',   map(     'header','true',     'cloudFiles.inferColumnTypes','true'   ) );

-- %%
CREATE OR REFRESH STREAMING TABLE bronze_revenue COMMENT "Raw Zomato revenue data" TBLPROPERTIES ("quality" = "bronze") AS SELECT   *,   _metadata.file_path AS input_file_path,   CURRENT_TIMESTAMP AS ingestion_timestamp FROM cloud_files(   '/Volumes/dlt_manas/my_schema/delta_live_tables/Landing/operational_data/zomato/revenue.csv',   'csv',   map(     'header','true',     'cloudFiles.inferColumnTypes','true'   ) );

-- %%
CREATE OR REFRESH STREAMING TABLE bronze_orderItems COMMENT "Raw Zomato orders items data" TBLPROPERTIES ("quality" = "bronze") AS SELECT   *,   _metadata.file_path AS input_file_path,   CURRENT_TIMESTAMP AS ingestion_timestamp FROM cloud_files(   '/Volumes/dlt_manas/my_schema/delta_live_tables/Landing/operational_data/zomato/order_items.csv',   'csv',   map(     'header','true',     'cloudFiles.inferColumnTypes','true'   ) );
